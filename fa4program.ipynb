# %% [markdown]
# <a href="https://colab.research.google.com/github/oolyvenubs-pixel/fa4programactivity/blob/main/fa4program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# problem 1
for number in range(1, 21):
  if number % 2 == 0:

     continue

print(number)
# Out:
# 20

# %%
#problem 2
correct_password = "zb1is9"

while True:
  user_input = input("Enter password: ")
  attempts += 1

  if user_input == correct_password:
    print("Access Granted.")
    break
  else:
    print("Acces Denied. Please try again.")
# Out:
# Enter password: zb1is9
# Access Granted.

# %%
#problem 3
for i in range(1,11):

  if i == 4:
    continue

  if i == 6:
    pass

  if i == 8:
    break

  print(i)
# Out:
# 1
# 2
# 3
# 5
# 6
# 7
